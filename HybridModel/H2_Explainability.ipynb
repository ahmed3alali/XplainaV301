# %% [markdown]
# # H2 Explainability
# Using SHAP and LIME...

# %%
# !pip install shap

# %%
import pandas as pd
from utils_explainability import explain_recommendation
print('Ready')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 from utils_explainability import explain_recommendation
#       3 print('Ready')
#
# File ~\Desktop\school\4th_year\term 2\course_recommendation1\XplainaV301\HybridModel\utils_explainability.py:3
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 import shap
#       4 import lime
#       5 import lime.lime_tabular
#
# ModuleNotFoundError: No module named 'shap'
